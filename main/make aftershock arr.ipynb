# %%
import numpy as np
import pandas as pd

# %%
path = '../data/pohang_aftershock.csv'
data = pd.read_csv(path)
data.head()
# Out:
#                    time  magnitude  latitude  longtitude
# 0  2017-11-15 14:29:31         5.4     36.11      129.37
# 1  2017-11-15 14:32:59         3.6     36.10      129.36
# 2  2017-11-15 14:46:00         2.5     36.12      129.39
# 3  2017-11-15 14:50:05         2.4     36.10      129.36
# 4  2017-11-15 14:52:55         2.4     36.11      129.35

# %%
latitude = data['latitude']
longtitude = data['longtitude']
latitude
# Out:
# 0      36.11
# 1      36.10
# 2      36.12
# 3      36.10
# 4      36.11
#        ...
# 464      NaN
# 465      NaN
# 466      NaN
# 467      NaN
# 468      NaN
# Name: latitude, Length: 469, dtype: float64

# %%
arr = []
for i in range(469) :
    arr.append((latitude[i],longtitude[i]))
arr
# Out:
# [(36.11, 129.37),
#  (36.1, 129.36),
#  (36.12, 129.39),
#  (36.1, 129.36),
#  (36.11, 129.35),
#  (36.1, 129.35),
#  (36.12, 129.37),
#  (36.11, 129.35),
#  (36.09, 129.34),
#  (36.11, 129.35),
#  (36.14, 129.38),
#  (36.09, 129.35),
#  (36.09, 129.33),
#  (36.12, 129.37),
#  (36.13, 129.36),
#  (36.09, 129.35),
#  (36.14, 129.36),
#  (36.12, 129.36),
#  (36.14, 129.37),
#  (36.08, 129.31),
#  (36.14, 129.37),
#  (36.09, 129.32),
#  (36.14, 129.38),
#  (36.14, 129.38),
#  (36.11, 129.35),
#  (36.1, 129.35),
#  (36.11, 129.35),
#  (36.1, 129.35),
#  (36.11, 129.36),
#  (36.14, 129.36),
#  (36.14, 129.38),
#  (36.1, 129.36),
#  (36.1, 129.36),
#  (36.13, 129.38),
#  (36.14, 129.35),
#  (36.09, 129.35),
#  (36.09, 129.35),
#  (36.14, 129.36),
#  (36.14, 129.37),
#  (36.08, 129.34),
#  (36.09, 129.34),
#  (36.12, 129.37),
#  (36.12, 129.37),
#  (36.1, 129.35),
#  (36.13, 129.37),
#  (36.1, 129.34),
#  (36.12, 129.36),
#  (36.11, 129.37),
#  (36.12, 129.36),
#  (36.12, 129.36),
# ...
